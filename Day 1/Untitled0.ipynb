# %%
milista=['netflix', 'hbo','disney']

# %%
milista
# Out:
# ['netflix', 'hbo', 'disney']

# %%
milista.append=()

# %%
#Acceder a columnas y contar valores

# %%
#acceder a ciertos valores por fila y columnas
netflix.iloc[[]]
